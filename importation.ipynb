# %%
import pandas as pd

# %%
df = pd.read_csv('Call Center_Dataset.csv')
df
# Out:
#                              id       customer_name      sentiment  \
# 0      DKK-57076809-w-055481-fU    Analise Gairdner        Neutral
# 1      QGK-72219678-w-102139-KY    Crichton Kidsley  Very Positive
# 2      GYJ-30025932-A-023015-LD   Averill Brundrett       Negative
# 3      ZJI-96807559-i-620008-m7     Noreen Lafflina  Very Negative
# 4      DDU-69451719-O-176482-Fm  Toma Van der Beken  Very Positive
# ...                         ...                 ...            ...
# 32936  BRM-96715111-h-155613-wO    Othelia Ouldcott        Neutral
# 32937  UJH-96531654-y-074703-H4    Tasha Cubbinelli       Negative
# 32938  WDS-58440679-I-064360-TT      Margaux Slaten       Negative
# 32939  FTZ-87704815-T-824288-iC           Odey Seed       Positive
# 32940  OOR-17971494-i-311571-PR      Mozelle Berlin       Negative
#
#        csat_score call_timestamp  Column1            reason            city  \
# 0             7.0     10/29/2020      NaN  Billing Question         Detroit
# ...

# %%
df.head(4)
# Out:
#                          id      customer_name      sentiment  csat_score  \
# 0  DKK-57076809-w-055481-fU   Analise Gairdner        Neutral         7.0
# 1  QGK-72219678-w-102139-KY   Crichton Kidsley  Very Positive         NaN
# 2  GYJ-30025932-A-023015-LD  Averill Brundrett       Negative         NaN
# 3  ZJI-96807559-i-620008-m7    Noreen Lafflina  Very Negative         1.0
#
#   call_timestamp  Column1            reason         city           state  \
# 0     10/29/2020      NaN  Billing Question      Detroit        Michigan
# 1      10/5/2020      NaN    Service Outage  Spartanburg  South Carolina
# 2      10/4/2020      NaN  Billing Question  Gainesville         Florida
# 3     10/17/2020      NaN  Billing Question     Portland          Oregon
#
#        channel response_time  call duration in minutes     call_center
# 0  Call-Center    Within SLA                        17  Los Angeles/CA
# 1      Chatbot    Within SLA                        23    Baltimore/MD
# ...
