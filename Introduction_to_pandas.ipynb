# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# - Reading the data we are given

# %%
student_df = pd.read_excel("Data_set_assignment.xlsx")
student_df.head()
# Out:
#   Access_no  Gender  Age        Course  DSC3108  DSC3114  MTH3108  SYE3104
# 0     A1001    Male   20  Computer Sci     85.0       78     92.0     88.0
# 1     A1002  Female   21      Business     76.0       82     75.0     80.0
# 2     A1003  Female   22   Engineering     90.0       85     88.0     91.0
# 3     A1004    Male   19       Nursing     65.0       70     80.0     75.0
# 4     A1005    Male   23  Computer Sci     88.0       79     91.0     84.0

# %%
## If it is from a different folder
bike_sals = pd.read_excel("H:\\Big_Data_with_R\\Assignment\\Bike_Sales.xlsx")
bike_sals = pd.read_excel("H:/Big_Data_with_R/Assignment/Bike_Sales.xlsx")

# %%
bike_sals.head()
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2017-01-01    1  January  2017            17           Youth (<25)
# 1 2017-01-01    1  January  2017            23           Youth (<25)
# 2 2017-01-01    1  January  2017            33  Young Adults (25-34)
# 3 2017-01-01    1  January  2017            39        Adults (35-64)
# 4 2017-01-01    1  January  2017            42        Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               M         Canada  British Columbia            Bikes
# 1               M      Australia          Victoria            Bikes
# 2               F         France           Yveline            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
bike_sals.describe(include="all")
# Out:
#                                  Date            Day   Month           Year  \
# count                          113036  113036.000000  113036  113036.000000
# unique                            NaN            NaN      12            NaN
# top                               NaN            NaN    June            NaN
# freq                              NaN            NaN   11234            NaN
# mean    2020-01-06 01:36:09.376127744      15.665753     NaN    2019.520153
# min               2017-01-01 00:00:00       1.000000     NaN    2017.000000
# 25%               2019-01-09 00:00:00       8.000000     NaN    2019.000000
# 50%               2019-10-16 00:00:00      16.000000     NaN    2019.500000
# 75%               2021-01-28 00:00:00      23.000000     NaN    2021.000000
# max               2021-12-31 00:00:00      31.000000     NaN    2021.000000
# std                               NaN       8.781567     NaN       1.179704
#
# ...

# %%
student_df.tail()
# Out:
#    Access_no  Gender  Age        Course  DSC3108  DSC3114  MTH3108  SYE3104
# 45     A1046  Female   22      Business     78.0       81     76.0     79.0
# 46     A1047    Male   19   Engineering     93.0       89     91.0     90.0
# 47     A1048  Female   21       Nursing     65.0       67     71.0     73.0
# 48     A1049    Male   22  Computer Sci     90.0       84     88.0     87.0
# 49     A1050  Female   20      Business     76.0       78     74.0     76.0

# %%
student_df.iloc[3:7]
# Out:
#   Access_no  Gender  Age        Course  DSC3108  DSC3114  MTH3108  SYE3104
# 3     A1004    Male   19       Nursing     65.0       70     80.0     75.0
# 4     A1005    Male   23  Computer Sci     88.0       79     91.0     84.0
# 5     A1006  Female   20      Business     70.0       75     73.0     78.0
# 6     A1007    Male   22   Engineering      NaN       90     85.0     89.0

# %%
student_df.loc[3:7]
# Out:
#   Access_no  Gender  Age        Course  DSC3108  DSC3114  MTH3108  SYE3104
# 3     A1004    Male   19       Nursing     65.0       70     80.0     75.0
# 4     A1005    Male   23  Computer Sci     88.0       79     91.0     84.0
# 5     A1006  Female   20      Business     70.0       75     73.0     78.0
# 6     A1007    Male   22   Engineering      NaN       90     85.0     89.0
# 7     A1008  Female   21       Nursing     60.0       65     70.0     67.0

# %%
student_df.dtypes
# Out:
# Access_no     object
# Gender        object
# Age            int64
# Course        object
# DSC3108      float64
# DSC3114        int64
# MTH3108      float64
# SYE3104      float64
# dtype: object

# %%
print("Rows---------------->%d\nColumns------------->%d"%(student_df.shape[0],student_df.shape[1]))
# Out:
# Rows---------------->50
# Columns------------->8

# %% [markdown]
# ## EDA
#
# Handling the missing values
# - NAN N/A NULL

# %%
## Missing values
missing_values = student_df.isna().any()
missing_values
# Out:
# Access_no    False
# Gender        True
# Age          False
# Course       False
# DSC3108       True
# DSC3114      False
# MTH3108       True
# SYE3104       True
# dtype: bool

# %%
missing_values = student_df.isna().sum()
missing_values
# Out:
# Access_no    0
# Gender       1
# Age          0
# Course       0
# DSC3108      2
# DSC3114      0
# MTH3108      1
# SYE3104      1
# dtype: int64

# %%
missing_values/len(student_df) * 100
# Out:
# Access_no    0.0
# Gender       2.0
# Age          0.0
# Course       0.0
# DSC3108      4.0
# DSC3114      0.0
# MTH3108      2.0
# SYE3104      2.0
# dtype: float64

# %% [markdown]
# ## Handling Missing Values
# - drop missing values
# - interporate
# - filling
# - imputation

# %%
## Dropping missing values
# axis
student_df
# Out:
#    Access_no  Gender  Age        Course  DSC3108  DSC3114  MTH3108  SYE3104
# 0      A1001    Male   20  Computer Sci     85.0       78     92.0     88.0
# 1      A1002  Female   21      Business     76.0       82     75.0     80.0
# 2      A1003  Female   22   Engineering     90.0       85     88.0     91.0
# 3      A1004    Male   19       Nursing     65.0       70     80.0     75.0
# 4      A1005    Male   23  Computer Sci     88.0       79     91.0     84.0
# 5      A1006  Female   20      Business     70.0       75     73.0     78.0
# 6      A1007    Male   22   Engineering      NaN       90     85.0     89.0
# 7      A1008  Female   21       Nursing     60.0       65     70.0     67.0
# 8      A1009    Male   19  Computer Sci     78.0       82     88.0     80.0
# 9      A1010  Female   22      Business     85.0       80     90.0      NaN
# 10     A1011    Male   20   Engineering     92.0       89     94.0     90.0
# ...

# %%
student_df.dropna(inplace=True)
student_df
# Out:
#    Access_no  Gender  Age        Course  DSC3108  DSC3114  MTH3108  SYE3104
# 0      A1001    Male   20  Computer Sci     85.0       78     92.0     88.0
# 1      A1002  Female   21      Business     76.0       82     75.0     80.0
# 2      A1003  Female   22   Engineering     90.0       85     88.0     91.0
# 3      A1004    Male   19       Nursing     65.0       70     80.0     75.0
# 4      A1005    Male   23  Computer Sci     88.0       79     91.0     84.0
# 5      A1006  Female   20      Business     70.0       75     73.0     78.0
# 7      A1008  Female   21       Nursing     60.0       65     70.0     67.0
# 8      A1009    Male   19  Computer Sci     78.0       82     88.0     80.0
# 10     A1011    Male   20   Engineering     92.0       89     94.0     90.0
# 11     A1012  Female   21       Nursing     68.0       72     75.0     70.0
# 12     A1013    Male   23  Computer Sci     81.0       76     88.0     83.0
# ...

# %%
student_df.dropna(axis=0, inplace=True) # deleting rows with missing values
student_df.dropna(axis=1, inplace=True) # deleting columns with missing values

# %% [markdown]
#  # Missing values Using
# - interporate
# - filling
# - imputation
